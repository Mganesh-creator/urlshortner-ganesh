# %%
t1=[1,2,3.5,2+3j,"ecec",'tkr']
print(t1,type(t1))
# Out:
# [1, 2, 3.5, (2+3j), 'ecec', 'tkr'] <class 'list'>

# %%
print(t1[2])
# Out:
# 3.5

# %%
t1.index('ecec')
# Out:
# 4

# %%
r2=[]
print(r2,type(r2))
# Out:
# [] <class 'list'>

# %%
r2.append('aakash')
print(r2)
# Out:
# ['aakash']

# %%
r2.extend(['kalyani','pranu'])
print(r2)
# Out:
# ['aakash', 'kalyani', 'pranu']

# %%
m1=[1,2,3]
m2=[3,4,5]
m2.extend(m1)
print(m2)
m2.index(3)
# Out:
# [3, 4, 5, 1, 2, 3]
# 0

# %%
print(m2)
m2.insert(3,7)
print(m2)
# Out:
# [3, 4, 5, 1, 2, 3, 7]
# [3, 4, 5, 7, 1, 2, 3, 7]

# %%
print(m1,m2)
m3=m1.copy()
print(m3)
# Out:
# [1, 2, 3] [3, 4, 5, 7, 1, 2, 3, 7]
# [1, 2, 3]

# %%
n1=[23,45,56]
n2=[12,23,34]
n3=n1.copy()
print(n1,n3)
# Out:
# [23, 45, 56] [23, 45, 56]

# %%
m4=[1,2,3,4,5]
print(m4)
m4.count(3)
# Out:
# [1, 2, 3, 4, 5]
# 1

# %%
#deletion
print(m1,m2,m3,m4)
m4.remove(4)
print(m4)
# Out:
# [1, 2, 3] [3, 4, 5, 7, 1, 2, 3, 7] [1, 2, 3] [1, 2, 3, 4, 5]
# [1, 2, 3, 5]

# %%
m4.pop()
print(m4)
# Out:
# [1, 2, 3]

# %%
m4=[10,20,30,40]
del m4
print(m1,m2,m3)
# Out:
# [1, 2, 3] [3, 4, 5, 7, 1, 2, 3, 7] [1, 2, 3]
