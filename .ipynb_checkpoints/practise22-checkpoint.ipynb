# %%
a="kalyani"
print(a)
# Out:
# kalyani

# %%
a=1
b=2
c=a+b
d=a-b
e=a*b
f=a/b
print(c,d,e,f)
# Out:
# 3 -1 2 0.5

# %%
a=10
b=19
c=a+b
print("c=",c)
# Out:
# c= 29

# %%
student="kalyani"
print('so beautiful...so elegant..just looking like a wow!,kalyani')
# Out:
# so beautiful...so elegant..just looking like a wow!,kalyani

# %%
pi=pi3
print(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pi=pi3
#       2 print(pi)
#
# NameError: name 'pi3' is not defined

# %%
print(a,type(a))
# Out:
# falseit is raining
# it is raining <class 'str'>

# %%
p="it is raining"
p1=bool(p)
print(p1,type(p1))
# Out:
# True <class 'bool'>

# %%
a="ur looking like an angel\n"
b=a*5
print(b)
# Out:
# ur looking like an angel
# ur looking like an angel
# ur looking like an angel
# ur looking like an angel
# ur looking like an angel

# %%
x=10
y=20
z=x//y
print(z)
# Out:
# 0

# %%
y=90
x=98
z=y-x
print(z)
# Out:
# -8

# %%
y=2
x=3
z=y**x
print(z)

# %%
a=80
print(a)
a1=int(input('enter a number'))

# %%
a="kallu"
print(a)

# %%
a="kallu"
print(a)
