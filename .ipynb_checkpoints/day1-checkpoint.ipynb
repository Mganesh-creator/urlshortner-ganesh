# %%
p=int(input("enter the number"))
    if i%3!==0:
        if i==2:
            print(i)
            else:
                if i%3!=0 and i%2!=0:
                    print(i)
                    else:
                        if i==3:
                            print(i)
# Out:
#   Cell In[6], line 2
#     if i%3!==0:
#     ^
# IndentationError: unexpected indent

# %%
p=int(input("enter a number"))
even=0
odd=0
i=0
while i<=p:
    if i%2==0:
        even+=i
    else:
            odd+=i
            i+=1 
            print("even")
            print("odd")
